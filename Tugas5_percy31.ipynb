# %% [markdown]
# ## Ade Irvan Kurniawan (percy31)

# %% [markdown]
# # Python OOP

# %% [markdown]
# ## 1. Apa itu OOP dan cobalah buat 2 implementasi konsep OOP menggunakan python!
#
# OOP python atau disebut objek oriented programming python adalah paradigma pemrograman yang menyediakan sarana untuk menyusun program sehingga properti dan perilaku/method digabungkan ke dalam objek individual yang disebut dengan kelas

# %%
# a) implementasi menggunakan OOP python
class Gaji:
  
  def  __init__(self,nama,jabatan,gaji,jam):
    try:
      self.nama = nama
      self.jabatan = jabatan
      self.gaji = gaji
      self.jam = jam
      self.lembur = 150000
      self.total_gaji = 0
    except Exception as eror:
      print(eror)
  
  def pendapatan(self):
    self.total_gaji += (self.gaji + (self.lembur*self.jam))
  
  def print_gaji(self):
    print(f" {self.nama} dengan jabatan {self.jabatan} memiliki gaji total {self.total_gaji} ")

# %%
andi = Gaji("Andi","IT Support",3000000,4)
reza = Gaji("Reza","Front End Dev",3500000,5)
andre = Gaji("Andre","Data Scientis",5000000,3)

# %%
andi.pendapatan()
reza.pendapatan()
andre.pendapatan()

# %%
andi.print_gaji()
reza.print_gaji()
andre.print_gaji()
# Out:
#  Andi dengan jabatan IT Support memiliki gaji total 3600000
#  Reza dengan jabatan Front End Dev memiliki gaji total 4250000
#  Andre dengan jabatan Data Scientis memiliki gaji total 5450000

# %%
# a) implementasi menggunakan OOP python
class Employee:
   empCount = 0

   def __init__(self, name, salary):
      self.name = name
      self.salary = salary
      Employee.empCount += 1
   
   def displayCount(self):
     print ("Total Employee ", Employee.empCount)

   def displayEmployee(self):
      print ("Name : ", self.name,  ", Salary: ", self.salary)

# %%
emp1 = Employee("Zara", 2000)
emp2 = Employee("Manni", 5000)

# %%
emp1.displayCount()
emp1.displayEmployee()
# Out:
# Total Employee  2
# Name :  Zara , Salary:  2000

# %% [markdown]
# ## 2. Sebut dan jelaskan 2 modul yang ada di python !
#
# - modul pandas => yaitu modul yang digunakan untuk handling data, dan membuat dataframe dari data dictionary / matriks
# - modul numpy => yaitu merupakan modul yang berfungsi untuk operasi matematika terutama matriks dan linear aljabar

# %% [markdown]
# ##3. Hitunglah berapa hasil dari √175 + 4√7 + (1/3) + ³log 81 menggunakan module math!

# %%
import math as m

# %%
a = m.sqrt(175) + (4*m.sqrt(7)) + (1/3) + m.log(81,3)
print(a)
# Out:
# 28.145095132914648

# %% [markdown]
# ## 4. Apa itu custom exception handling dan berikan 1 contoh implementasinya!
#
# exception handling , adalah penanganan error pada python, yaitu apabila error terjadi, maka seluruh program tidak akan berhenti, dan program akan menampilkan error tersebut

# %%
try:
  a = int(input("masukkan nilai penyebut : "))
  z = 10
except Exception as error:
  print(error)
print("nilai z adalah ",z)
# Out:
# masukkan nilai penyebut : lima
# invalid literal for int() with base 10: 'lima'
# nilai z adalah  10

# %% [markdown]
# # Artificial Intelligence

# %% [markdown]
# ##1. Apa perbedaan dari structured dan unstructured data dan sebutkan 3 sumber data!
#
# - data terstruktur adalah data yang berbentuk tabular, memiliki kolom dan baris, isi berupa angka dan teks
# - data tak terstruktur adalah data yang tidak berbentuk tabular, dan belum ada informasi yang bisa dilihat secara langsung tanpa mengelolanya, berupa (gambar,suara,vidio,log chat sosmed)
#
# **sumber data :**
# 1. Mysql
# 2. sensus penduduk
# 3. data customer pada e-commerce

# %% [markdown]
# ## 2. Jelaskan perbedaan AI, Machine Learning dan Deep Learning!
#
# - AI adalah Teknik apa pun yang
# memungkinkan komputer meniru
# kecerdasan manusia.
# - Machine Learning adalah Bagian dari AI
# yang memungkinkan mesin untuk
# mengerjakan tugas dengan lebih baik,
# dengan pengalaman.
# - Bagian dari ML yang
# memungkinkan software melatih dirinya
# sendiri untuk melakukan tugas dengan
# data dalam jumlah besar.

# %% [markdown]
# ##  3. Apa perbedaan Machine Learning dengan Tradisional software?
#
# - pada machine learning , kita hanya perlu memasukkan data dan jawaban pada algoritma , yang berujuan untuk mendapatkan pola dari hubungan antara input dengan output. sehingga dapat mempridiksi suatu output dari input yg ada
# - sedangkan tradisional software yaitu kita hanya perlu memasukkan aturan dan data (input) , sehingga komputer bekerja sesuai yg kita perintahkan saja.

# %% [markdown]
# ## 4. Sebutkan 3 contoh aplikasi Machine Learning di sektor smart city dan agriculture!
#
#
#
# **Smart City**
# - penerapan Corona Likelihood Metric atau CLM , yang dapat mendeteksi resiko terjangkit virus corona
# - E-tilang yang memdudahkan petugas dalam mengurangi pelanggaran dijalan raya, dan menumbuhkan kesadaran bagi pengendara
# - Sistem Face Recognition diChina, yang terhubung dengan score credit
#
# **Agriculture**
# - pengelompokan status etahan pangan suatu daerah dengan menggunakan fuzzy c-means
# - Perusahaan robotika FJ Dynamics menerapkan AI untuk mentransformasikan pertanian tradisional dengan kekuatan data. pemanfaatan data telah membantu petani untuk memutuskan kapan harus mulai menanam, kapan bisa panen, jenis tanaman apa yang akan ditanam, berapa banyak pupuk dan bahan kimia lainnya yang perlu digunakan, serta seberapa sering mengairi ladang.
# - Penerapan Machine learning berbasis DATA GEOSPASIAL untuk optimalisasi lahan pertanian pada masa pandemi dengan menggunakan algoritma klasifikasi random forest

# %% [markdown]
# # Maths for AI

# %% [markdown]
# ## 1. Mengapa ilmu matematika penting ketika mempelajari AI?
#
# karena dengan ilmu matematika kita dapat memodelkan AI untuk melaksanakan tugas tertentu, dan komunikasi dengan mesin sendiri/komputer juga menggunakan matematika

# %% [markdown]
# ## 2. Jelaskan perbedaan vektor dan skalar!
#
# - vektor adalah besaran yang memiliki nilai dan arah
# - skalar adalah besarran yang hanya memiliki nilai

# %% [markdown]
# ## 3. Apa perbedaan dari Jarak Euclidean dan Manhattan?
#
#
# - jarak euclidean adalah jarak yang langsung menghubungkan antara titik a dan titik b pada sistem koordinat secara linier, atau secara pythagoras
# -  sedangakn jarak manhattan adalah jarak yang mengubungkan titik a dengan titik b, secara tegak lurus, dari titik a ke titik 0, dan dari titik 0 ketitik b

# %% [markdown]
# ## 4. Apa kegunaan matriks dalam ilmu matematika ketika menerapkan AI?
#
#
# kegunaan matrik yaitu, digunakan untuk komputasi data pada AI, baik data gambar maupun data numerik. dan kenapa AI menggunakan matriks, karena matrik lebih ceopat dalam dioperasi pada komputer.

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## 1. Jelaskan perbedaan supervised dan unsupervised learning dan sebutkan 2 contohnya!
#
# 1. supervised learning adalah algortima yang digunaka untuk menentukan hubungan antara data dengan memberikan training dataset pada mesin.
#  - Naive Bayes
#  - regresi linear
#
# 2. unsupervised learning adalah algortima yang digunakan untuk menentukan pola baru dari suatu data yang berguna dalam sebagai pandangan baru dalam mengambil keputusan.
#  - Fuzzy
#  - klastering-means

# %% [markdown]
# ## 2. Sebutkan setiap tahap yang ada di Machine Learning life cycle dan jelaskan!
#
#
# - mengumpulkan data
# - mengolah data
# - menyiapkan model yang akan dipakai
# - training data
# - evaluasi
# - tuning hasil evaluasi
# - membuat prediksi

# %% [markdown]
# ## 3. Apa perbedaan regression dengan clustering?
#
# - regression adalah adalah menentukan model dari data output terhadap data input yang sudah ada/tersedia, untuk meencari model yang digunakan untuk prediksi
# - clustering adalah mengelompokkan data berdasarkan dengan kelas - kelas yang memiliki kemiripan hampir sama dan memisahkan antar kelas dengan meminimkan kemiripan

# %% [markdown]
# ## 4. Apa itu algoritma Artificial Neural Network dan untuk apa fungsinya?
#
# ANN adalah algortima yang dapat bekerja dengan prinsip saraf manusia, yang dapat mengolah data tak terstruktur dengan jumlah yang banyak, serta data yang tidak berlabel seperti gambar, video, dan juga suara.
