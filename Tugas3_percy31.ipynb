# %% [markdown]
# ##**Tugas 3**
#
# **Nama : Ade Irvan Kurniawan**
#
# **ID   : Percy31**

# %% [markdown]
# **1. Penerapan Machine Vision**
#
#
# 1.   Aplikasi untuk menghitung jumlah pengunjung / jumlah orang yang keluar dan masuk suatu bangunan. cara kerja dari penerapan machine vision ini yaitu dengan menggunakan object detection, kita pasang sebuah garis sebagai selection posisi, dimana saat bounding objek ini melewati garis mke bawah dikatakan masuk, sedangkan saat menuju ke arah luar dikatakan keluar dan jumlah orang masuk berkurang
# ![MV1.png](data:image/png;base64,...)
# 2.   dengan menggunakan object detection dan plat number detection, kita dapat mendeteksi pelanggaran lalu lintas. dengan cara memberikan bounding box pada kendaraan dijalan raya, dimana terdapat garis lurus yang merupakan marka jalan, yang mana saat kendaraan melewati marka, maka bounding nya akan berwarna merah. lalu dengan menggunakan model plat number detection. dapat diterapkan sistem online. bagi pelanggar yang melanggar maka akan dikenakan bounty berupa penambahan jumlah pajak kendaraan yang dibayarkan.
# ![MV2.png](data:image/png;base64,...)

# %% [markdown]
# **2. Penerapan Natural Languange Processing**
#
#
# 1.   Personal assisten online seperti Ok google,Cortana, dan Alexa, yang dapat merespon petunjuk - petunjuk vokal dan melaksanakan perintah seperti menyetel lagu lewat youtube dan mencari informasi lewat penelusuran google
# 2.   Aplikasi seperti Gojek dan Grab sudah menggunakan NLP sehingga dapat menyebutkan nama lokasi/jalan yang natural di telinga manusia. dan juga google voice pada google maps yang dapat menyebutkan nama serta jalan dengan bahasa yang menyesuaikan settingan ponsel.
# 3.   Aplikasi Email seperti Gmail, Hotmail, Ymail yang memfilter dan mengklasifikasikan email menggunakan NLP sehingga saat ada email masuk ke dalam inbox dapat mendeteksi spam dan memindahkannya ke folder spam agar kita tidak perlu membacanya.

# %% [markdown]
# **3. Penerapan Data Science**
#
#
# 1.   Adanya penyesuaian etelase barang yang dijual pada E-Commerce dengan kebutuhan, minat, dan tingakt pendapatan konsumen, contohnya seperti Tokopedia, Shopee, dan Bukalapak yang sudah semakin marak bermunculan dan tidak sedikit orang-orang yang memilih berbelanja secara online melalui situs sejenis ini. penyesuaian otomatis seperti ini berdasarkan data pembeli. Dengan mengubah tata letak halaman dan menyesuaikan produk yang dijualnya secara otomatis dan real-time.
# 2.   Fraud Detection atau mendeteksi penipuan pada industri keuangan, sehingga data science dan Artificial Intelligence (AI) adalah kedua ilmu yang sering digunakan untuk melakukan proses ini. Fungsi data science lainnya dalam bidang fraud detection adalah dapat membantu untuk memblokir sesi atau akun jika terdeteksi terdapat aktivitas keuangan yang tidak normal dengan analisis prediksi real - time.
# 3.  Penetapan harga dinamis pada umumnya digunakan oleh suatu perusahaan dengan menggunakan data untuk mensegmentasikan pelanggan atau konsumen secara akurat. Sehingga setiap kelompok pelanggan atau konsumen ke depannya akan dapat ditawari produk dengan harga yang berbeda. Penggunaan algoritma dynamic pricing pada suatu perusahaan biasanya memperhitungkan dari berbagai macam kategori, misalnya saja seperti lead time, review properti, dan fasilitas yang telah disediakan.
