# %%
import numpy as np
# Create an array
civilian_birth = np.array([4352, 233, 3245, 256, 2394])
civilian_birth

np.zeros((3, 6)) # special arrays with numpy

np.linspace(0, 1, 5) # 0 to 1 (inclusive) with 5 points

a = np.array([0, 1])
b = np.array([2, 3])
ab = np.stack((a, b)).T # stacking arrays
print(ab)
# Out:
# [[0 2]
#  [1 3]]

# %%
floatVar = 3.145
intVar = floatVar.asty
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
A = np.array([[4,5],[6,-3]]) 
b = np.array([23, 3]) 
x,y = np.linalg.solve(A,b) 
print("value of x = ",x,"\n value of y = ",y)

matrix = np.matrix([[1, 5, 3], [9, 5, 6], [2, 8, 9]])
matrix.flatten() # Flatten matrix

np.linalg.det(matrix)  # Return determinant of matrix

matrix.diagonal().sum()  # Calculate the trace of the matrix

np.linalg.inv(matrix) # Calculate inverse of matrix
# Out:
# value of x =  2.0
#  value of y =  3.0
# matrix([[ 0.01851852,  0.12962963, -0.09259259],
#         [ 0.42592593, -0.01851852, -0.12962963],
#         [-0.38271605, -0.01234568,  0.24691358]])

# %%
A = np.array([[4,5],[6,-3]]) 
A
np.linalg.inv(A)
# Out:
# array([[ 0.07142857,  0.11904762],
#        [ 0.14285714, -0.0952381 ]])

# %%
matrix = np.matrix([[1, 5, 3], [9, 5, 6], [2, 8, 9]])
matrix
# Out:
# matrix([[1, 5, 3],
#         [9, 5, 6],
#         [2, 8, 9]])

# %%
matrix.diagonal().sum()  # Calculate the trace of the matrix
# Out:
# 15

# %%
matrix.flatten() # Flatten matrix
# Out:
# matrix([[1, 5, 3, 9, 5, 6, 2, 8, 9]])

# %% [markdown]
# # Pandas

# %%
import pandas as pd
data = ['a','b','c','d']
s = pd.Series(data) # creating a pandas series
print(s)

data = {'name': ['Jason', 'Molly', 'Tina', 'Jake'], 
        'year': [2012, 2012, 2013, 2014], 'reports': [4, 24, 31, 2]}
index = ['Cochice', 'Pima', 'Santa Cruz', 'Maricopa']
df = pd.DataFrame(data, index = index) # Create an dataframe
df
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object
#              name  year  reports
# Cochice     Jason  2012        4
# Pima        Molly  2012       24
# Santa Cruz   Tina  2013       31
# Maricopa     Jake  2014        2

# %%
# Load a csv
url = 'https://raw.githubusercontent.com/anshupandey/WileyNXT/main/DataEngineering/datawh.csv'
df = pd.read_csv(url)
df.head(2)

# Load a JSON file
url = 'https://raw.githubusercontent.com/anshupandey/WileyNXT/main/DataEngineering/server-metrics.json'
df = pd.read_json(url)
df.head(2)

# Save dataframe as csv in the working director
df.to_csv('server_data.csv')

# %%
traindata = df [["dates", "Server"]]
traindata
# Out:
#             dates     Server
# 0   1525046400000  Server_02
# 1   1525132800000  Server_02
# 2   1525219200000   Server_0
# 3   1525305600000  Server_01
# 4   1525392000000   Server_0
# 5   1525478400000  Server_01
# 6   1525564800000  Server_01
# 7   1525651200000  Server_01
# 8   1525737600000  Server_02
# 9   1525824000000  Server_01
# 10  1525910400000   Server_0
# 11  1525996800000   Server_0
# 12  1526083200000  Server_01
# 13  1526169600000  Server_02
# 14  1526256000000  Server_02
# 15  1526342400000   Server_0
# 16  1526428800000  Server_01
# 17  1526515200000  Server_02
# 18  1526601600000  Server_02
# 19  1526688000000  Server_02

# %%
df[1:2]
# Out:
#    id          dates  Accepted  Rejected    App     Server
# 1   1  1525132800000      2592       182  App_3  Server_02

# %%
# Pandas: Selection and Filtering
import pandas as pd
data = {'name': ['Jason', 'Molly', 'Tina'], 
        'year': [2012, 2012, 2013], 
        'reports': [4, 5, 9],
        'coverage': [25, 62, 70]}
df = pd.DataFrame(data)
df['name'] # View Column

df[['name', 'reports']] # View Two Columns

df[:2] # View First Two Rows

df[df['coverage'] > 50] # Rows Where Coverage>50

# View Rows Where Coverage > 20 & Reports < 6
df[(df['coverage']  > 20) & (df['reports'] < 6)]
# Out:
#     name  year  reports  coverage
# 0  Jason  2012        4        25
# 1  Molly  2012        5        62

# %%
df[df['coverage'] > 50] # Rows Where Coverage>50
# Out:
#     name  year  reports  coverage
# 1  Molly  2012        5        62
# 2   Tina  2013        9        70

# %%
df
# Out:
#     name  year  reports  coverage
# 0  Jason  2012        4        25
# 1  Molly  2012        5        62
# 2   Tina  2013        9        70

# %% [markdown]
# # Pandas Data Aggregation

# %%
#groupby
import pandas as pd
data = {'name': ['Jen', 'Max', 'Tina', 'John', 'Kay', 'Ish', 'Ami'], 
        'year': [2012, 2012, 2013, 2012, 2013, 2014, 2014], 
        'score': [4, 5, 9, 8, 9, 5, 4]}
df = pd.DataFrame(data)
df
# calculating year wise average score
df.groupby(['year'])['score'].mean()
# Out:
# year
# 2012    5.666667
# 2013    9.000000
# 2014    4.500000
# Name: score, dtype: float64

# %%
df
# Out:
#    name  year  score
# 0   Jen  2012      4
# 1   Max  2012      5
# 2  Tina  2013      9
# 3  John  2012      8
# 4   Kay  2013      9
# 5   Ish  2014      5
# 6   Ami  2014      4

# %%
# basic Statistical 
import pandas as pd
data = {'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'age': [42, 52, 36, 42, 73], 
        'score': [4, 24, 31, 2, 3]}
df = pd.DataFrame(data)
df.describe().T #Summary statistics

print("Mean of score ", end = '');print(df['score'].mean())
print("Median of score ", end = '');print(df['score'].median())
print("Mode of age ", end = '');print(df['age'].mode())
print("Variance of age ", end = '');print(df['age'].var())
print("Skewness of age ", end = '');print(df['age'].skew())
# Out:
# Mean of score 12.8
# Median of score 4.0
# Mode of age 0    42
# dtype: int64
# Variance of age 213.0
# Skewness of age 1.4700997201463943

# %%
df
# Out:
#     name  age  score
# 0  Jason   42      4
# 1  Molly   52     24
# 2   Tina   36     31
# 3   Jake   42      2
# 4    Amy   73      3

# %%
# Data transformation with map
import pandas as pd
data = {'names': ['Jen K Forst', 'Max M brown', 'Tina W Musk',
                 'John M Gates', 'Kay W Carter', 'Ish T Sodhi'],
        'score': [4, 5, 9, 8, 9, 5]}
df = pd.DataFrame(data)
df.T # transpose the matrix

def get_code(name): # get initial for every name
    return "".join([k[0].upper() for k in name.split(' ')])
# Creating a column with initials
df['code'] = df['names'].map(get_code)
df.T
# Out:
#                  0            1            2             3             4  \
# names  Jen K Forst  Max M brown  Tina W Musk  John M Gates  Kay W Carter
# score            4            5            9             8             9
# code           JKF          MMB          TWM           JMG           KWC
#
#                  5
# names  Ish T Sodhi
# score            5
# code           ITS

# %%
# Data transformation with replace
import pandas as pd
data = {'name': ['Jen K Forst', 'Max M Brown', 'Tina W Musk',
                 'John M Gates', 'Kay W Carter', 'Ish T Sodhi'],
        'score': [4, 5, 9, 8, 9, 5]}
df = pd.DataFrame(data)
df.T

dfrep = df.replace("Jen K Forst",'Jennifer K Forest',inplace=False)
dfrep.T
# Out:
#                        0            1            2             3  \
# name   Jennifer K Forest  Max M Brown  Tina W Musk  John M Gates
# score                  4            5            9             8
#
#                   4            5
# name   Kay W Carter  Ish T Sodhi
# score             9            5

# %%
df.T
# Out:
#                  0            1            2             3             4  \
# name   Jen K Forst  Max M Brown  Tina W Musk  John M Gates  Kay W Carter
# score            4            5            9             8             9
#
#                  5
# name   Ish T Sodhi
# score            5

# %%
# binning in pandas make a categorical
import pandas as pd
data = {'name': ['Jen', 'Max', 'Tina', 'John', 'Kay', 'Ish', 'Ami'], 
        'year': [2012, 2012, 2013, 2012, 2013, 2014, 2014], 
        'score': [4, 5, 9, 8, 9, 6, 4]}
df = pd.DataFrame(data)

# creating a categorical attribute for score
df['score_cat'] = pd.cut(df['score'],bins=[0,3,6,10],
                         labels=['Low','Medium','High'])
df.T
# Out:
#                 0       1     2     3     4       5       6
# name          Jen     Max  Tina  John   Kay     Ish     Ami
# year         2012    2012  2013  2012  2013    2014    2014
# score           4       5     9     8     9       6       4
# score_cat  Medium  Medium  High  High  High  Medium  Medium

# %% [markdown]
# # MATPLOTLIB

# %%
import matplotlib.pyplot as plt
year = [2010,2015,2020]
growth = [45,68,82]

plt.figure(figsize=(10,4))
plt.plot(year,growth)
plt.xlabel("Year")
plt.ylabel("Growth")
plt.title("Year wise growth")
plt.show()

# %%
#pIE cHART
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
fracs = [15, 35, 45, 10]
explode = (0, 0.05, 0, 0)

plt.figure(figsize=(5,5))
plt.pie(fracs, labels=labels, autopct='%1.2f%%', shadow=True)
plt.show()

# %%
# bar
import matplotlib.pyplot as plt
year = [2010,2015,2020]
growth = [45,58,82]

plt.figure(figsize=(10,4))
plt.bar(year,growth,color=['lightblue','orange','lightgreen'])
#plt.plot(year,growth)
plt.xlabel("Year")
plt.ylabel("Growth")
plt.title("Year wise growth")
plt.show()

# %%
import numpy
mu, sigma = 100, 15
x = mu + sigma * numpy.random.randn(10000)

n, bins, patches = plt.hist(x, 20, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60,.025,r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# # Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", color_codes=True)
tips = sns.load_dataset("tips")

plt.figure(figsize=(12,4))
plt.subplot(121)
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
plt.subplot(122)
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips)
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Heatmap
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", color_codes=True)
tips = sns.load_dataset("tips")

sns.heatmap(tips.corr(),annot=True,cmap='coolwarm')
plt.show()
